# %%
import requests

# %%
API_KEY ="AIzaSyDfdDGsTfMa9zXqr3PliFemr_4jge0dPos"

# %%
import requests
import pandas as pd

# Define your API key and base URL
api_key = "AIzaSyDfdDGsTfMa9zXqr3PliFemr_4jge0dPos"  # Replace with your actual API key
url = "https://www.googleapis.com/books/v1/volumes"

# Define function to extract and transform data into desired schema
def extract_book_details(items, search_key):
    books = []
    for item in items:
        volume_info = item.get("volumeInfo", {})
        sale_info = item.get("saleInfo", {})
        list_price = sale_info.get("listPrice", {})
        retail_price = sale_info.get("retailPrice", {})
        
        books.append({
            "book_id": item.get("id", "N/A"),
            "search_key": search_key,
            "book_title": volume_info.get("title", "N/A"),
            "book_subtitle": volume_info.get("subtitle", "N/A"),
            "book_authors": ", ".join(volume_info.get("authors", ["N/A"])),
            "book_description": volume_info.get("description", "N/A"),
            "industryIdentifiers": ", ".join([f"{id['type']}: {id['identifier']}" for id in volume_info.get("industryIdentifiers", [])]),
            "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
            "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
            "pageCount": volume_info.get("pageCount", 0),
            "categories": ", ".join(volume_info.get("categories", ["N/A"])),
            "language": volume_info.get("language", "N/A"),
            "imageLinks": volume_info.get("imageLinks", {}).get("thumbnail", "N/A"),
            "ratingsCount": volume_info.get("ratingsCount", 0),
            "averageRating": volume_info.get("averageRating", 0.0),
            "country": sale_info.get("country", "N/A"),
            "saleability": sale_info.get("saleability", "N/A"),
            "isEbook": sale_info.get("isEbook", False),
            "amount_listPrice": list_price.get("amount", 0.0),
            "currencyCode_listPrice": list_price.get("currencyCode", "N/A"),
            "amount_retailPrice": retail_price.get("amount", 0.0),
            "currencyCode_retailPrice": retail_price.get("currencyCode", "N/A"),
            "buyLink": sale_info.get("buyLink", "N/A"),
            "year": volume_info.get("publishedDate", "N/A"),
            "publisher": volume_info.get("publisher", "N/A"),
        })
    return books

# Function to fetch data and handle pagination
def fetch_books(search_key, max_results=1000):
    start_index = 0
    books_data = []
    
    while start_index < max_results:
        params = {
            "q": search_key,
            "startIndex": start_index,
            "maxResults": 40,  # Max allowed per API call
            "key": api_key
        }
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break  # No more items to fetch
            books_data.extend(extract_book_details(items, search_key))
            start_index += 40  # Increment to fetch the next page
        else:
            print(f"Failed with status code: {response.status_code}")
            print(response.json())
            break
    
    return books_data

# Fetch data for a specific search key
search_key = "python programming"
books_data = fetch_books(search_key)

# Convert to DataFrame
books_df = pd.DataFrame(books_data)

# Save to a CSV file
books_df.to_csv("books_data.csv", index=False)
print(books_df.head())
# Out:
#         book_id          search_key  \
# 0  v1jvDwAAQBAJ  python programming
# 1  ePyeNz2Eoy8C  python programming
# 2  J93uzwEACAAJ  python programming
# 3  69IyAgAAQBAJ  python programming
# 4  aJQILlLxRmAC  python programming
#
#                                           book_title  \
# 0                     LEARN PYTHON WITH 200 PROGRAMS
# 1                                    Learning Python
# 2                             Python Tutorial 3.11.3
# 3  Introduction to Computation and Programming Us...
# 4                                 Python Programming
#
#                                  book_subtitle  \
# 0  PRACTICAL GUIDE FOR CBSE XI,XII & BEGINEERS
# 1         Powerful Object-Oriented Programming
# 2                                          N/A
# 3                                          N/A
# 4          An Introduction to Computer Science
#
#                                 book_authors  \
# 0                          VAISHALI B BHAGAT
# ...

# %%
books_df
# Out:
#           book_id          search_key  \
# 0    v1jvDwAAQBAJ  python programming
# 1    ePyeNz2Eoy8C  python programming
# 2    J93uzwEACAAJ  python programming
# 3    69IyAgAAQBAJ  python programming
# 4    aJQILlLxRmAC  python programming
# ..            ...                 ...
# 740  vWuoRnWvKGwC  python programming
# 741  saMbAQAAMAAJ  python programming
# 742  rMiYaAcwjtUC  python programming
# 743  -jw8AAAAMAAJ  python programming
# 744  hWfIdtOwLRoC  python programming
#
#                                             book_title  \
# 0                       LEARN PYTHON WITH 200 PROGRAMS
# 1                                      Learning Python
# 2                               Python Tutorial 3.11.3
# 3    Introduction to Computation and Programming Us...
# 4                                   Python Programming
# ..                                                 ...
# 740                                 The Musical Leader
# ...

# %%
import requests
import pandas as pd

# Define your API key and base URL
api_key = "AIzaSyDfdDGsTfMa9zXqr3PliFemr_4jge0dPos"  # Replace with your actual API key
url = "https://www.googleapis.com/books/v1/volumes"

# Define function to extract and transform data into desired schema
def extract_book_details(items, search_key):
    books = []
    for item in items:
        volume_info = item.get("volumeInfo", {})
        sale_info = item.get("saleInfo", {})
        list_price = sale_info.get("listPrice", {})
        retail_price = sale_info.get("retailPrice", {})
        
        books.append({
            "book_id": item.get("id", "N/A"),
            "search_key": search_key,
            "book_title": volume_info.get("title", "N/A"),
            "book_subtitle": volume_info.get("subtitle", "N/A"),
            "book_authors": ", ".join(volume_info.get("authors", ["N/A"])),
            "book_description": volume_info.get("description", "N/A"),
            "industryIdentifiers": ", ".join([f"{id['type']}: {id['identifier']}" for id in volume_info.get("industryIdentifiers", [])]),
            "text_readingModes": volume_info.get("readingModes", {}).get("text", False),
            "image_readingModes": volume_info.get("readingModes", {}).get("image", False),
            "pageCount": volume_info.get("pageCount", 0),
            "categories": ", ".join(volume_info.get("categories", ["N/A"])),
            "language": volume_info.get("language", "N/A"),
            "imageLinks": volume_info.get("imageLinks", {}).get("thumbnail", "N/A"),
            "ratingsCount": volume_info.get("ratingsCount", 0),
            "averageRating": volume_info.get("averageRating", 0.0),
            "country": sale_info.get("country", "N/A"),
            "saleability": sale_info.get("saleability", "N/A"),
            "isEbook": sale_info.get("isEbook", False),
            "amount_listPrice": list_price.get("amount", 0.0),
            "currencyCode_listPrice": list_price.get("currencyCode", "N/A"),
            "amount_retailPrice": retail_price.get("amount", 0.0),
            "currencyCode_retailPrice": retail_price.get("currencyCode", "N/A"),
            "buyLink": sale_info.get("buyLink", "N/A"),
            "year": volume_info.get("publishedDate", "N/A"),
            "publisher": volume_info.get("publisher", "N/A"),
        })
    return books

# Function to fetch data and handle pagination
def fetch_books(search_key, max_results=300):
    start_index = 0
    books_data = []
    
    while start_index < max_results:
        params = {
            "q": search_key,
            "startIndex": start_index,
            "maxResults": 40,  # Max allowed per API call
            "key": api_key
        }
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break  # No more items to fetch
            books_data.extend(extract_book_details(items, search_key))
            start_index += 40  # Increment to fetch the next page
        else:
            print(f"Failed with status code: {response.status_code}")
            print(response.json())
            break
    
    return books_data

# Fetch data for a specific search key
search_key = "Data Science"
books_data = fetch_books(search_key)

# Convert to DataFrame
books_df1 = pd.DataFrame(books_data)

# Save to a CSV file
books_df1.to_csv("books_data.csv", index=False)
print(books_df1.head())
# Out:
#         book_id    search_key                           book_title  \
# 0  vfi3DQAAQBAJ  Data Science                   R for Data Science
# 1  xb29DwAAQBAJ  Data Science         Introduction to Data Science
# 2  JYodCAAAQBAJ  Data Science            Data Science from Scratch
# 3  t-ncDwAAQBAJ  Data Science  Data Science Uncovering the Reality
# 4  -nt8DwAAQBAJ  Data Science                         Data Science
#
#                                        book_subtitle  \
# 0  Import, Tidy, Transform, Visualize, and Model ...
# 1     Data Analysis and Prediction Algorithms with R
# 2                       First Principles with Python
# 3  IITians uncover how Data Science is transformi...
# 4                              Concepts and Practice
#
#                                         book_authors  \
# 0                  Hadley Wickham, Garrett Grolemund
# 1                                 Rafael A. Irizarry
# 2                                          Joel Grus
# ...

# %%
books_df1
# Out:
#           book_id    search_key  \
# 0    vfi3DQAAQBAJ  Data Science
# 1    xb29DwAAQBAJ  Data Science
# 2    JYodCAAAQBAJ  Data Science
# 3    t-ncDwAAQBAJ  Data Science
# 4    -nt8DwAAQBAJ  Data Science
# ..            ...           ...
# 315  FwULEAAAQBAJ  Data Science
# 316  1bslCQAAQBAJ  Data Science
# 317  LWcKEAAAQBAJ  Data Science
# 318  wYH3EAAAQBAJ  Data Science
# 319  QOqiEAAAQBAJ  Data Science
#
#                                             book_title  \
# 0                                   R for Data Science
# 1                         Introduction to Data Science
# 2                            Data Science from Scratch
# 3                  Data Science Uncovering the Reality
# 4                                         Data Science
# ..                                                 ...
# 315                               Engineering Research
# 316  Data Science, Learning by Latent Structures, a...
# 317                                 Medical Statistics
# ...

# %%
import pandas as pd
books_df.to_csv("books_df.csv", index=False)

# %%
import pandas as pd
books_df1.to_csv("books_df1.csv", index=False)

# %%
import numpy as np

# %%
import numpy as np
books_df['book_subtitle'] = books_df['book_subtitle'].replace('N/A', 'None')
books_df['book_authors'] = books_df['book_authors'].replace('N/A', 'None')
books_df['book_description'] = books_df['book_description'].replace('N/A', 'None')
books_df['industryIdentifiers'] = books_df['industryIdentifiers'].replace('N/A', 'None')
books_df['text_readingModes'] = books_df['text_readingModes'].replace('N/A', 'None')
books_df['image_readingModes'] = books_df['image_readingModes'].replace('N/A', 'None')
books_df['pageCount'] = books_df['pageCount'].replace('N/A', '0')
books_df['categories'] = books_df['categories'].replace('N/A', 'None')
books_df['language'] = books_df['language'].replace('N/A', 'None')
books_df['imageLinks'] = books_df['imageLinks'].replace('N/A', 'None')
books_df['ratingsCount'] = books_df['ratingsCount'].replace('N/A', '0')
books_df['averageRating'] = books_df['averageRating'].replace('N/A', '0.0')
books_df['country'] = books_df['country'].replace('N/A', 'None')
books_df['saleability'] = books_df['saleability'].replace('N/A', 'None')
books_df['isEbook'] = books_df['isEbook'].replace('N/A', 'None')
books_df['amount_listPrice'] = books_df['amount_listPrice'].replace('N/A', '0.0')
books_df['currencyCode_listPrice'] = books_df['currencyCode_listPrice'].replace('N/A', 'None')
books_df['amount_retailPrice'] = books_df['amount_retailPrice'].replace('N/A', '0.00')
books_df['currencyCode_retailPrice'] = books_df['currencyCode_retailPrice'].replace('N/A', 'None')
books_df['buyLink'] = books_df['buyLink'].replace('N/A', 'None')
books_df['year'] = books_df['year'].replace('N/A', 'None')
books_df['publisher'] = books_df['publisher'].replace('N/A', 'None')

# %%
books_df
# Out:
#           book_id          search_key  \
# 0    v1jvDwAAQBAJ  python programming
# 1    ePyeNz2Eoy8C  python programming
# 2    J93uzwEACAAJ  python programming
# 3    69IyAgAAQBAJ  python programming
# 4    aJQILlLxRmAC  python programming
# ..            ...                 ...
# 740  vWuoRnWvKGwC  python programming
# 741  saMbAQAAMAAJ  python programming
# 742  rMiYaAcwjtUC  python programming
# 743  -jw8AAAAMAAJ  python programming
# 744  hWfIdtOwLRoC  python programming
#
#                                             book_title  \
# 0                       LEARN PYTHON WITH 200 PROGRAMS
# 1                                      Learning Python
# 2                               Python Tutorial 3.11.3
# 3    Introduction to Computation and Programming Us...
# 4                                   Python Programming
# ..                                                 ...
# 740                                 The Musical Leader
# ...

# %%
import numpy as np
books_df1['book_subtitle'] = books_df['book_subtitle'].replace('N/A', 'None')
books_df1['book_authors'] = books_df['book_authors'].replace('N/A', 'None')
books_df1['book_description'] = books_df['book_description'].replace('N/A', 'None')
books_df1['industryIdentifiers'] = books_df['industryIdentifiers'].replace('N/A', 'None')
books_df1['text_readingModes'] = books_df['text_readingModes'].replace('N/A', 'None')
books_df1['image_readingModes'] = books_df['image_readingModes'].replace('N/A', 'None')
books_df1['pageCount'] = books_df['pageCount'].replace('N/A', '0')
books_df1['categories'] = books_df['categories'].replace('N/A', 'None')
books_df1['language'] = books_df['language'].replace('N/A', 'None')
books_df1['imageLinks'] = books_df['imageLinks'].replace('N/A', 'None')
books_df1['ratingsCount'] = books_df['ratingsCount'].replace('N/A', '0')
books_df1['averageRating'] = books_df['averageRating'].replace('N/A', '0.0')
books_df1['country'] = books_df['country'].replace('N/A', 'None')
books_df1['saleability'] = books_df['saleability'].replace('N/A', 'None')
books_df1['isEbook'] = books_df['isEbook'].replace('N/A', 'None')
books_df1['amount_listPrice'] = books_df['amount_listPrice'].replace('N/A', '0.0')
books_df1['currencyCode_listPrice'] = books_df['currencyCode_listPrice'].replace('N/A', 'None')
books_df1['amount_retailPrice'] = books_df['amount_retailPrice'].replace('N/A', '0.00')
books_df1['currencyCode_retailPrice'] = books_df['currencyCode_retailPrice'].replace('N/A', 'None')
books_df1['buyLink'] = books_df['buyLink'].replace('N/A', 'None')
books_df1['year'] = books_df['year'].replace('N/A', 'None')
books_df1['publisher'] = books_df['publisher'].replace('N/A', 'None')

# %%
books_df1
# Out:
#           book_id    search_key  \
# 0    vfi3DQAAQBAJ  Data Science
# 1    xb29DwAAQBAJ  Data Science
# 2    JYodCAAAQBAJ  Data Science
# 3    t-ncDwAAQBAJ  Data Science
# 4    -nt8DwAAQBAJ  Data Science
# ..            ...           ...
# 315  FwULEAAAQBAJ  Data Science
# 316  1bslCQAAQBAJ  Data Science
# 317  LWcKEAAAQBAJ  Data Science
# 318  wYH3EAAAQBAJ  Data Science
# 319  QOqiEAAAQBAJ  Data Science
#
#                                             book_title  \
# 0                                   R for Data Science
# 1                         Introduction to Data Science
# 2                            Data Science from Scratch
# 3                  Data Science Uncovering the Reality
# 4                                         Data Science
# ..                                                 ...
# 315                               Engineering Research
# 316  Data Science, Learning by Latent Structures, a...
# 317                                 Medical Statistics
# ...

# %%
books_df.columns
# Out:
# Index(['book_id', 'search_key', 'book_title', 'book_subtitle', 'book_authors',
#        'book_description', 'industryIdentifiers', 'text_readingModes',
#        'image_readingModes', 'pageCount', 'categories', 'language',
#        'imageLinks', 'ratingsCount', 'averageRating', 'country', 'saleability',
#        'isEbook', 'amount_listPrice', 'currencyCode_listPrice',
#        'amount_retailPrice', 'currencyCode_retailPrice', 'buyLink', 'year',
#        'publisher'],
#       dtype='object')

# %%
books_df1.columns
# Out:
# Index(['book_id', 'search_key', 'book_title', 'book_subtitle', 'book_authors',
#        'book_description', 'industryIdentifiers', 'text_readingModes',
#        'image_readingModes', 'pageCount', 'categories', 'language',
#        'imageLinks', 'ratingsCount', 'averageRating', 'country', 'saleability',
#        'isEbook', 'amount_listPrice', 'currencyCode_listPrice',
#        'amount_retailPrice', 'currencyCode_retailPrice', 'buyLink', 'year',
#        'publisher'],
#       dtype='object')

# %%
books_df.isnull().sum()
# Out:
# book_id                     0
# search_key                  0
# book_title                  0
# book_subtitle               0
# book_authors                0
# book_description            0
# industryIdentifiers         0
# text_readingModes           0
# image_readingModes          0
# pageCount                   0
# categories                  0
# language                    0
# imageLinks                  0
# ratingsCount                0
# averageRating               0
# country                     0
# saleability                 0
# isEbook                     0
# amount_listPrice            0
# currencyCode_listPrice      0
# amount_retailPrice          0
# currencyCode_retailPrice    0
# buyLink                     0
# year                        0
# publisher                   0
# dtype: int64

# %%
books_df1.isnull().sum()
# Out:
# book_id                     0
# search_key                  0
# book_title                  0
# book_subtitle               0
# book_authors                0
# book_description            0
# industryIdentifiers         0
# text_readingModes           0
# image_readingModes          0
# pageCount                   0
# categories                  0
# language                    0
# imageLinks                  0
# ratingsCount                0
# averageRating               0
# country                     0
# saleability                 0
# isEbook                     0
# amount_listPrice            0
# currencyCode_listPrice      0
# amount_retailPrice          0
# currencyCode_retailPrice    0
# buyLink                     0
# year                        0
# publisher                   0
# dtype: int64

# %%
books_df.shape
# Out:
# (745, 25)

# %%
books_df1.shape
# Out:
# (320, 25)

# %%
pd.concat([books_df,books_df1])
# Out:
#           book_id          search_key  \
# 0    v1jvDwAAQBAJ  python programming
# 1    ePyeNz2Eoy8C  python programming
# 2    J93uzwEACAAJ  python programming
# 3    69IyAgAAQBAJ  python programming
# 4    aJQILlLxRmAC  python programming
# ..            ...                 ...
# 315  FwULEAAAQBAJ        Data Science
# 316  1bslCQAAQBAJ        Data Science
# 317  LWcKEAAAQBAJ        Data Science
# 318  wYH3EAAAQBAJ        Data Science
# 319  QOqiEAAAQBAJ        Data Science
#
#                                             book_title  \
# 0                       LEARN PYTHON WITH 200 PROGRAMS
# 1                                      Learning Python
# 2                               Python Tutorial 3.11.3
# 3    Introduction to Computation and Programming Us...
# 4                                   Python Programming
# ..                                                 ...
# 315                               Engineering Research
# ...

# %%
books=pd.concat([books_df,books_df1])
books
# Out:
#           book_id          search_key  \
# 0    v1jvDwAAQBAJ  python programming
# 1    ePyeNz2Eoy8C  python programming
# 2    J93uzwEACAAJ  python programming
# 3    69IyAgAAQBAJ  python programming
# 4    aJQILlLxRmAC  python programming
# ..            ...                 ...
# 315  FwULEAAAQBAJ        Data Science
# 316  1bslCQAAQBAJ        Data Science
# 317  LWcKEAAAQBAJ        Data Science
# 318  wYH3EAAAQBAJ        Data Science
# 319  QOqiEAAAQBAJ        Data Science
#
#                                             book_title  \
# 0                       LEARN PYTHON WITH 200 PROGRAMS
# 1                                      Learning Python
# 2                               Python Tutorial 3.11.3
# 3    Introduction to Computation and Programming Us...
# 4                                   Python Programming
# ..                                                 ...
# 315                               Engineering Research
# ...

# %%
books.isnull().sum()
# Out:
# book_id                     0
# search_key                  0
# book_title                  0
# book_subtitle               0
# book_authors                0
# book_description            0
# industryIdentifiers         0
# text_readingModes           0
# image_readingModes          0
# pageCount                   0
# categories                  0
# language                    0
# imageLinks                  0
# ratingsCount                0
# averageRating               0
# country                     0
# saleability                 0
# isEbook                     0
# amount_listPrice            0
# currencyCode_listPrice      0
# amount_retailPrice          0
# currencyCode_retailPrice    0
# buyLink                     0
# year                        0
# publisher                   0
# dtype: int64

# %%
books.columns
# Out:
# Index(['book_id', 'search_key', 'book_title', 'book_subtitle', 'book_authors',
#        'book_description', 'industryIdentifiers', 'text_readingModes',
#        'image_readingModes', 'pageCount', 'categories', 'language',
#        'imageLinks', 'ratingsCount', 'averageRating', 'country', 'saleability',
#        'isEbook', 'amount_listPrice', 'currencyCode_listPrice',
#        'amount_retailPrice', 'currencyCode_retailPrice', 'buyLink', 'year',
#        'publisher'],
#       dtype='object')

# %%
books.shape
# Out:
# (1065, 25)

# %%
import pandas as pd
books.to_csv("books.csv", index=False)

# %%
from sqlalchemy import create_engine

username = "root"
password = "Raghavi@1598".replace('@','%40')
host = "127.0.0.1"
port = 3306
database = "bookapi"

connection_string = f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(connection_string)
with engine.connect() as connection:
    print("connection successful!")
# Out:
# connection successful!

# %%
engine= create_engine(connection_string)
books.to_sql(
    name="books",
    con=engine,
    index=False,
    if_exists="replace",
    chunksize=10000)
# Out:
# 1065

# %%
"Check Availability of eBooks vs Physical Books",
"Find the Publisher with the Most Books Published",
            "Identify the Publisher with the Highest Average Rating",
            "Get the Top 5 Most Expensive Books by Retail Price",
            "Find Books Published After 2010 with at Least 500 Pages",
            "List Books with Discounts Greater than 20%",
            "Find the Average Page Count for eBooks vs Physical Books",
            "Find the Top 3 Authors with the Most Books",
            "List Publishers with More than 10 Books",
            "Find the Average Page Count for Each Category",
            "Retrieve Books with More than 3 Authors",
            "Books with Ratings Count Greater Than the Average",
            "Books with the Same Author Published in the Same Year",
            "Books with a Specific Keyword in the Title",
            "Year with the Highest Average Book Price",
            "Count Authors Who Published 3 Consecutive Years",
            "Authors Published in the Same Year under Different Publishers",
            "Average Price of eBooks vs Physical Books",
            "Outlier Books by Average Rating",
            "Publisher with Highest Average Rating (More Than 10 Books)"
